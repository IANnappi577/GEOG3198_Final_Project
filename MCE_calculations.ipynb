# %% [markdown]
# # MCE calculations
#
# Goals:
# - Rescale all variables to a common scale: Normalize values on the scale of 0-1 using min-max normalization
# - Determine the appropriate MCE weight for each variable
# - Perform the weighted average of all variables to get a final MCE score
# - Plot the MCE score on the map per census tract

# %%
# Import modules
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Code here
# Example of a code cell
